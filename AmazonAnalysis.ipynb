# %%
#Connect The Library
import pandas as pd

#Load The Data
amazon=pd.read_csv("/content/drive/MyDrive/Amazon.csv")

# %%
#Display The Data
amazon
# Out:
#       product_id                                       product_name  \
# 0     B002PD61Y4  D-Link DWA-131 300 Mbps Wireless Nano USB Adap...
# 1     B002PD61Y4  D-Link DWA-131 300 Mbps Wireless Nano USB Adap...
# 2     B002SZEOLG  TP-Link Nano USB WiFi Dongle 150Mbps High Gain...
# 3     B003B00484  Duracell Plus AAA Rechargeable Batteries (750 ...
# 4     B003L62T7W  Logitech B100 Wired USB Mouse, 3 yr Warranty, ...
# ...          ...                                                ...
# 1460  B0BPCJM7TB  WIDEWINGS Electric Handheld Milk Wand Mixer Fr...
# 1461  B0BPJBTB3F  Khaitan ORFin Fan heater for Home and kitchen-...
# 1462  B0BQ3K23Y1  Oratech Coffee Frother electric, milk frother ...
# 1463  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 1464  B0BR4F878Q  Swiffer Instant Electric Water Heater Faucet T...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|NetworkingDevices|Networ...             ₹507
# ...

# %%
#Check the Data Info
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
#Check Columns And Rows
amazon.shape
# Out:
# (1465, 16)

# %%
#Check Columns Name
amazon.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %% [markdown]
# <h2><u>According to the Data Information some columns have Object Datatype firstly we needs to remove currency sign from these columns</u><h2>

# %%
#Change the Datatypes
amazon["discounted_price"]=amazon["discounted_price"].str.replace("₹","").str.replace(",","")
amazon["discounted_price"] = pd.to_numeric(amazon["discounted_price"], errors='coerce').fillna(0).astype(int)

amazon["actual_price"]=amazon["actual_price"].str.replace("₹","").str.replace(",","")
amazon["actual_price"] = pd.to_numeric(amazon["actual_price"], errors='coerce').fillna(0).astype(int)

#Check The Column After changes
print(amazon[["discounted_price","actual_price"]])
# Out:
#       discounted_price  actual_price
# 0                  507          1208
# 1                  507          1208
# 2                  749          1339
# 3                  399           499
# 4                  279           375
# ...                ...           ...
# 1460               259           999
# 1461              1299          2495
# 1462               279           499
# 1463               249           999
# 1464              1439          1999
#
# [1465 rows x 2 columns]

# %%
#Check the null Values
amazon.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# <h2><u>No Null Values are present in Dataset</u><h2>

# %%
amazon.describe()
# Out:
#        discounted_price   actual_price
# count       1465.000000    1465.000000
# mean        3125.305119    5444.989078
# std         6944.305791   10874.827327
# min           39.000000      39.000000
# 25%          325.000000     800.000000
# 50%          799.000000    1650.000000
# 75%         1999.000000    4295.000000
# max        77990.000000  139900.000000

# %%
#1.How does the discount percentage affect the rating of a product?

# Non-numeric values ko NaN mein convert karke handle karna
amazon["rating"] = pd.to_numeric(amazon["rating"], errors='coerce')

# NaN values ko fill karna (0 ya kisi aur suitable value se)
amazon["rating"] = amazon["rating"].fillna(0)

# Float se round karke integer mein convert karna
amazon["rating"] = amazon["rating"].round().astype(int)



dis_per_rating=amazon.groupby(["discount_percentage"])["rating"].mean().reset_index().sort_values(by="rating",ascending=False).head(10)
dis_per_rating
# Out:
#    discount_percentage    rating
# 62                 66%  4.136364
# 13                 21%  4.071429
# 24                 31%  4.071429
# 16                 24%  4.071429
# 72                 75%  4.068966
# 20                 28%  4.066667
# 21                 29%  4.062500
# 51                 56%  4.058824
# 28                 35%  4.055556
# 40                 46%  4.047619

# %%
#Plotting The Data
import matplotlib.pyplot as plt

plt.plot(dis_per_rating["discount_percentage"], dis_per_rating["rating"], marker='o')
plt.xlabel("Discount Percentage")
plt.ylabel("Average Rating")
plt.title("Effect of Discount Percentage on Product Rating")
plt.show()

# %%
#2.Which category has the highest average rating?

#Split the Category Data
amazon["New_category"]=amazon["category"].str.split("|").str[0]
category_high_rating=amazon.groupby(["New_category"])["rating"].mean()
category_high_rating
# Out:
# New_category
# Car&Motorbike            4.000000
# Computers&Accessories    4.000000
# Electronics              3.986692
# Health&PersonalCare      4.000000
# Home&Kitchen             3.973214
# HomeImprovement          4.000000
# MusicalInstruments       4.000000
# OfficeProducts           4.000000
# Toys&Games               4.000000
# Name: rating, dtype: float64

# %%
#Plotting The Data

import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.bar(category_high_rating.index,category_high_rating.values,color="coral",width=0.75)
plt.title("Category High Rating")
plt.xlabel("Category Name")
plt.ylabel("Average Rating")
plt.grid()
plt.show()

# %%
#3.Is there a correlation between the product's price and its rating?

cor_product_rating=amazon["actual_price"].corr(amazon["rating"])
print(f"Correlation between the Product Price and its Rating:{cor_product_rating}")
# Out:
# Correlation between the Product Price and its Rating:0.0694037614825514

# %% [markdown]
# <h2>The correlation value of 0.0694 is very close to 0, which indicates that there is no significant linear relationship between the product price and its rating. In this case, the correlation between actual_price and rating is very weak and positive. This means there is no noticeable effect of the price on the rating, and changes in price do not have a significant impact on the product's rating.<2>

# %%
#plotting The Data

import matplotlib.pyplot as plt

plt.scatter(amazon["actual_price"], amazon["rating"])
plt.xlabel("Product Price")
plt.ylabel("Rating")
plt.title("Correlation between Product Price and Rating")
plt.show()

# %%
#4.What is the most common word in the positive and negative reviews?

from collections import Counter
import pandas as pd
import re

# Assuming you have your Amazon review data in a pandas DataFrame called df
# Replace this with the actual loading of your dataset

# Split the reviews into words (lowercase, remove non-alphabetic characters)
def clean_and_split(text):
    # Remove non-alphabetic characters and split by space
    words = re.findall(r'\b\w+\b', text.lower())  # lowercasing and splitting into words
    return words

# Filter reviews by positive (e.g., rating >= 3) and negative (rating < 3) ratings
positive_reviews = amazon[amazon['rating'] >= 3]['review_title']
negative_reviews = amazon[amazon['rating'] < 3]['review_title']

# Apply the cleaning and word-splitting function
positive_words = ' '.join(positive_reviews.dropna()).lower()
negative_words = ' '.join(negative_reviews.dropna()).lower()

positive_word_list = clean_and_split(positive_words)
negative_word_list = clean_and_split(negative_words)

# Count the frequency of each word
positive_word_counts = Counter(positive_word_list)
negative_word_counts = Counter(negative_word_list)

# Most common word in positive reviews
most_common_positive_word = positive_word_counts.most_common(1)

# Most common word in negative reviews
most_common_negative_word = negative_word_counts.most_common(1)

print("Most common word in positive reviews:", most_common_positive_word)
print("Most common word in negative reviews:", most_common_negative_word)
# Out:
# Most common word in positive reviews: [('good', 3928)]
# Most common word in negative reviews: [('product', 5)]

# %%
#5.What is the distribution of ratings across all products?

rating_distribution = amazon["rating"].value_counts().sort_index()
rating_distribution
# Out:
# rating
# 0       1
# 2       2
# 3      40
# 4    1393
# 5      29
# Name: count, dtype: int64

# %%
# Plotting the rating distribution
import matplotlib.pyplot as plt
plt.bar(rating_distribution.index, rating_distribution.values)
plt.xlabel("Rating")
plt.ylabel("Count")
plt.title("Distribution of Ratings Across All Products")
plt.show()

# %%
#6.Which product has the highest number of reviews and what is its rating?
pro_high_review=amazon.groupby(["product_name"])["rating"].count().reset_index().sort_values(by="rating",ascending=False).head(15)
pro_high_review
# Out:
#                                            product_name  rating
# 384   Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...       5
# 386   Fire-Boltt Phoenix Smart Watch with Bluetooth ...       4
# 380   Fire-Boltt India's No 1 Smartwatch Brand Talk ...       3
# 324   Duracell USB C To Lightning Apple Certified (M...       3
# 390   Fire-Boltt Visionary 1.78" AMOLED Bluetooth Ca...       3
# 975   Samsung Galaxy M13 5G (Aqua Green, 6GB, 128GB ...       3
# 84    Amazon Basics USB Type-C to USB-A 2.0 Male Fas...       3
# 1023  Sounce Fast Phone Charging Cable & Data Sync U...       3
# 325   Duracell USB Lightning Apple Certified (Mfi) B...       3
# 1158  Wayona Nylon Braided USB to Lightning Fast Cha...       3
# 834   Portronics Konnect L POR-1081 Fast Charging 3A...       3
# 134   Ambrane Unbreakable 60W / 3A Fast Charging 1.5...       3
# 1271  boAt Micro USB 55 Tangle-free, Sturdy Micro US...       3
# 125   Ambrane 60W / 3A Fast Charging Output Cable wi...       3
# ...

# %%
product_name=pro_high_review.iloc[0]
pro_review_count=pro_high_review.max()
print(f"The product with the highest number of review is: {product_name}")
# Out:
# The product with the highest number of review is: product_name    Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# rating                                                          5
# Name: 384, dtype: object

# %%
#7.Identify the top 5 users who have given the most reviews?
top_5=amazon.groupby("user_id")["review_title"].count().reset_index().sort_values(by="review_title",ascending=False).head(5)
top_5
# Out:
#                                                 user_id  review_title
# 1048  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...            10
# 623   AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...             8
# 674   AGAELRYPMTG5SADZPDYB343EASAA,AGFN4JODOM2NTFCJQ...             8
# 88    AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...             7
# 254   AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...             7

# %%
print(f"The Top 5 Users who have given the most reviews:")
print(f"{top_5}")
# Out:
# The Top 5 Users who have given the most reviews:
#                                                 user_id  review_title
# 1048  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...            10
# 623   AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...             8
# 674   AGAELRYPMTG5SADZPDYB343EASAA,AGFN4JODOM2NTFCJQ...             8
# 88    AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...             7
# 254   AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...             7
